# %%
import DeepNeuralNetworkSleep.hdf5_files.datasets_extraction as DE
import os
import numpy as np
import h5py

# %%
file = 'D:/EEG_Data_stage/datasets/intra_cranial_dataset.h5'

# %%
features, scores = DE.training_dataset(file, [0, 1, 2, 3, 4], [15000, 1000, 13000, 2500, 4700],
                                       ["2", "7", "15", "28", "31", "87"])

# %%
print(features, scores)
# Out:
# [[ 0.66204131  0.69353593  0.63258031 ... -0.63790083  0.09001632
#    0.82932329]
#  [ 0.1037349   0.98671241  0.48483946 ... -0.04637269 -0.60594903
#    0.22659023]
#  [ 0.3704473   0.31652897  0.86409085 ...  0.42593329  0.2601526
#    0.59425928]
#  ...
#  [ 0.27474766  0.42814816  0.93464333 ...  0.43479133  0.26888872
#    0.60358134]
#  [ 0.13183611  0.49284191  0.94437747 ...  0.11616163  0.25836784
#    0.61382424]
#  [ 0.10552198  0.91362818  0.69136153 ...  0.01146272 -0.51028629
#    0.20660573]] [0 4 3 ... 3 2 4]
