# %%
import DeepNeuralNetworkSleep.hdf5_files.datasets_extraction as DE
import os
import numpy as np
import h5py

# %% [markdown]
# ## Load and prepare files

# %%
file = 'D:/EEG_Data_stage/datasets/intra_cranial_dataset.h5'
output = 'D:/EEG_Data_stage/datasets/'

# %% [markdown]
# ## Define the state names and amounts per state to use in training

# %%
features_training, scores_training, features_test, scores_test = DE.training_dataset(
    file, [0, 1, 2, 3, 4], [15000, 1000, 13000, 2500, 4700],
                                       ["2", "7", "15", "28", "31", "87"])

# %%
print(type(features), type(scores))
np.save(os.path.join(output, 'features'), features)
np.save(os.path.join(output, 'scores'), scores)
# Out:
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>
