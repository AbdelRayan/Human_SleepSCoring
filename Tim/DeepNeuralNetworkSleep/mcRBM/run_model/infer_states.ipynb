# %%
from configparser import ConfigParser
import subprocess
import os
os.chdir('C:\\Users\\timmi\PycharmProjects\AutomatedSleepScoring\Human_SleepSCoring\Tim\DeepNeuralNetworkSleep\mcRBM\scripts')
import argparse
from testDataset import testDataset
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\timmi\AppData\Local\Temp\ipykernel_31036\680866261.py:4: SyntaxWarning: invalid escape sequence '\P'
#   os.chdir('C:\\Users\\timmi\PycharmProjects\AutomatedSleepScoring\Human_SleepSCoring\Tim\DeepNeuralNetworkSleep\mcRBM\scripts')

# %%
root_dir = 'C:/Users/timmi/PycharmProjects/AutomatedSleepScoring/Human_SleepSCoring/Tim/DeepNeuralNetworkSleep/mcRBM/configuration_files/'
expFile = 'exp_details_test'
inputConfiguration = 'input_configuration'

# %%
new_dataset = testDataset(root_dir, expFile)
new_dataset.loadData()

new_dataset.prepareFile()
config = ConfigParser()
config.read(f'{root_dir}{expFile}')

exp_ID = config.get('EXP_DETAILS', 'expID')
exps_dir = config.get('EXP_DETAILS', 'expsDir')
dset_dir = config.get('EXP_DETAILS', 'dsetDir')
states_file = config.get('EXP_DETAILS', 'statesFile')

config.read(f'{root_dir}{inputConfiguration}')
num_fac = config.get('MODEL_PARAMETER_SETTING', 'num_fac')
num_hid_cov = config.get('MODEL_PARAMETER_SETTING', 'num_hid_cov')
num_hid_mean = config.get('MODEL_PARAMETER_SETTING', 'num_hid_mean')

model_name = f'weights/ws_temp800.mat'

# %%
base_dir = f"{exps_dir}{exp_ID}/"
print(base_dir)
print(dset_dir)
print(model_name)
print(states_file)
# Out:
# C:/Users/timmi/PycharmProjects/AutomatedSleepScoring/Human_SleepSCoring/Tim/DeepNeuralNetworkSleep/mcRBM/sample_data/experiments/Intra_cranial_Human_exp_2/
# C:/Users/timmi/PycharmProjects/AutomatedSleepScoring/Human_SleepSCoring/Tim/DeepNeuralNetworkSleep/mcRBM/sample_data/input/
# weights/ws_temp800.mat
# test_scores.mat

# %%
import numpy as np
def inspect_npz(filepath):
    print(f"Inspecting: {filepath}\n")

    data = np.load(filepath)
    print("Keys:", data.files)

    for key in data.files:
        arr = data[key]
        print(f"{key}: shape={arr.shape}, dtype={arr.dtype}")

inspect_npz(r"C:\Users\timmi\PycharmProjects\AutomatedSleepScoring\Human_SleepSCoring\Tim\DeepNeuralNetworkSleep\mcRBM\sample_data\input\test_features.npz")
# Out:
# Inspecting: C:\Users\timmi\PycharmProjects\AutomatedSleepScoring\Human_SleepSCoring\Tim\DeepNeuralNetworkSleep\mcRBM\sample_data\input\test_features.npz
#
# Keys: ['d', 'epochsLinked', 'epochTime']
# d: shape=(5670, 13), dtype=float64
# epochsLinked: shape=(5670, 4), dtype=int64
# epochTime: shape=(5670, 3), dtype=float64

# %%
command = f"python C:/Users/timmi/PycharmProjects/AutomatedSleepScoring/Human_SleepSCoring/Tim/DeepNeuralNetworkSleep/mcRBM/scripts/infer_states.py -f {base_dir} -done True -input {dset_dir} -md {base_dir} -m {model_name} -s {states_file}"
result = subprocess.run(
    command,
    shell=True,
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE,
    text=True
)

print("STDOUT:\n", result.stdout)
print("STDERR:\n", result.stderr)
print("Return code:", result.returncode)
# Out:
# STDOUT:
#  Initialization...
# args.f : C:/Users/timmi/PycharmProjects/AutomatedSleepScoring/Human_SleepSCoring/Tim/DeepNeuralNetworkSleep/mcRBM/sample_data/experiments/Intra_cranial_Human_exp_2/
# args.done : True
# args.md C:/Users/timmi/PycharmProjects/AutomatedSleepScoring/Human_SleepSCoring/Tim/DeepNeuralNetworkSleep/mcRBM/sample_data/experiments/Intra_cranial_Human_exp_2/
# args.input C:/Users/timmi/PycharmProjects/AutomatedSleepScoring/Human_SleepSCoring/Tim/DeepNeuralNetworkSleep/mcRBM/sample_data/input/
# args.m : weights/ws_temp800.mat
# args.s : test_scores.mat
# finalModel: weights/ws_temp800.mat
# Loading data...
# Analysing experiment :  C:\Users\timmi\PycharmProjects\AutomatedSleepScoring\Human_SleepSCoring\Tim\DeepNeuralNetworkSleep\mcRBM\sample_data\experiments\Intra_cranial_Human_exp_2
# Inspecting: visData.npz
#
# Keys: ['data', 'obsKeys', 'epochTime']
# data: shape=(7168, 13), dtype=float32
# obsKeys: shape=(7168, 4), dtype=float32
# epochTime: shape=(7168, 3), dtype=float64
# STATES:  (2268,)
# Computing latent states...
# C:/Users/timmi/PycharmProjects/AutomatedSleepScoring/Human_SleepSCoring/Tim/DeepNeuralNetworkSleep/mcRBM/sample_data/experiments/Intra_cranial_Human_exp_2/weights/ws_temp800.mat
# Transposed self.d to match model visible dimension.
# logisticArg_c shape: (7168, 11)
# logisticArg_c min: -851.8084547468479
# logisticArg_c max: 2.0927655600849087
# logisticArg_c mean: -9.651382885736687
# all finite: True
# logisticArg_m shape: (7168, 10)
# logisticArg_m min: -59.353626
# logisticArg_m max: 75.0466
# logisticArg_m mean: 8.068284
# all finite: True
# Storing in... C:\Users\timmi\PycharmProjects\AutomatedSleepScoring\Human_SleepSCoring\Tim\DeepNeuralNetworkSleep\mcRBM\sample_data\experiments\Intra_cranial_Human_exp_2\analysis\epoch800
#
# STDERR:
#  C:\Users\timmi\PycharmProjects\AutomatedSleepScoring\Human_SleepSCoring\Tim\DeepNeuralNetworkSleep\mcRBM\scripts\infer_states.py:160: RuntimeWarning: overflow encountered in exp
#   return 1. / (1. + np.exp(-x))
# C:\Users\timmi\PycharmProjects\AutomatedSleepScoring\Human_SleepSCoring\Tim\DeepNeuralNetworkSleep\mcRBM\scripts\infer_states.py:61: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   if not os.path.isdir('epoch%d' % self.epochID):
# C:\Users\timmi\PycharmProjects\AutomatedSleepScoring\Human_SleepSCoring\Tim\DeepNeuralNetworkSleep\mcRBM\scripts\infer_states.py:64: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   os.chdir('epoch%d' % self.epochID)
# C:\Users\timmi\PycharmProjects\AutomatedSleepScoring\Human_SleepSCoring\Tim\DeepNeuralNetworkSleep\mcRBM\scripts\infer_states.py:76: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   image.save('./hcActivation/%i.png' % self.epochID)
# C:\Users\timmi\PycharmProjects\AutomatedSleepScoring\Human_SleepSCoring\Tim\DeepNeuralNetworkSleep\mcRBM\scripts\infer_states.py:80: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   resized_image.save('./hmActivation/%i.png' % self.epochID)
# C:\Users\timmi\PycharmProjects\AutomatedSleepScoring\Human_SleepSCoring\Tim\DeepNeuralNetworkSleep\mcRBM\scripts\infer_states.py:88: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   plt.savefig('./binaryActivation/%i.png' % self.epochID)
# Traceback (most recent call last):
#   File "C:\Users\timmi\PycharmProjects\AutomatedSleepScoring\Human_SleepSCoring\Tim\DeepNeuralNetworkSleep\mcRBM\scripts\infer_states.py", line 277, in <module>
#     model.computeStates()
#     ~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\timmi\PycharmProjects\AutomatedSleepScoring\Human_SleepSCoring\Tim\DeepNeuralNetworkSleep\mcRBM\scripts\infer_states.py", line 97, in computeStates
#     inferredStates = np.column_stack((
#         np.zeros(len(self.binary_latentActivation)),
#         self.states['downsampledStates'].astype(int).flatten()[:len(self.binary_latentActivation)]))
#   File "C:\Users\timmi\miniconda3\Lib\site-packages\numpy\lib\_shape_base_impl.py", line 662, in column_stack
#     return _nx.concatenate(arrays, 1)
#            ~~~~~~~~~~~~~~~^^^^^^^^^^^
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 7168 and the array at index 1 has size 2268
#
# Return code: 1
